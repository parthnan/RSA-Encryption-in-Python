# %%
import math as math
import sympy as sympy
import random
import sys 

def gcd( a, b) : 
    if (a < b) : 
        return gcd(b, a) 
    if (a % b == 0) : 
        return b 
    return gcd(b, a % b) 

def power(base, exponent, n):
    base = sympy.Integer(base)
    exponent = sympy.Integer(exponent)
    is_neg = exponent < 0
    if is_neg:
        exponent = -exponent
    n = sympy.Integer(n)
    x = sympy.Integer(1)
    e = exponent
    c = sympy.Mod(base, n)
    vals = [c]
    x += 1
    while x <= exponent:
        c = sympy.Mod(c**2, n)
        vals.append(c)
        x *= 2

    x /= 2
    answer = sympy.Integer(1)
    while len(vals) > 0:
        nextv = vals.pop()
        if x <= e:
            answer = sympy.Mod(nextv*answer, n)
            e -= x
            if e == 0:
                break
        x /= 2
    if is_neg:
        answer = modinv(answer, n)
    return answer

#k= Fermatを行う回数
def fermat_test(n, k):
    if n == 1:
        return 0
    if n == 2:
        return 1
    for i in range(k):
        a = random.randint(1, n-1)
        if(gcd(a,n)==1):
            if pow(a, n-1, n) != 1:
                return 0
    return 1

def gen_prime(number,kaisuu) :
    listprime=[]
    count=0
    i=0
    while i<number:
        n=random.getrandbits(512)
        if n % 2 == 0:
            continue
        if n % 3 == 0:
            continue
        if(fermat_test(n, kaisuu)==1):
            i=i+1
            listprime.append(n)
            count=count+sympy.isprime(n)
    return (i,count,count/i,listprime)

print("Fermat Testを通したpの数、実際に素数のpの数、Fermat Testの当てはまり度、pのリスト")
print("回数=1")
print(gen_prime(100,1) )
# Out:
# Fermat Testを通したpの数、実際に素数のpの数、Fermat Testの当てはまり度、pのリスト
# 回数=1
# ...

# %%
print("Fermat Testを通したpの数、実際に素数のpの数、Fermat Testの当てはまり度、pのリスト")
print("回数=2")
print(gen_prime(100,2) )
# Out:
# Fermat Testを通したpの数、実際に素数のpの数、Fermat Testの当てはまり度、pのリスト
# 回数=2
# ...

# %%
print("Fermat Testを通したpの数、実際に素数のpの数、Fermat Testの当てはまり度、pのリスト")
print("回数=3")
print(gen_prime(100,3) )
# Out:
# Fermat Testを通したpの数、実際に素数のpの数、Fermat Testの当てはまり度、pのリスト
# 回数=3
# ...

# %%
print("Fermat Testを通したpの数、実際に素数のpの数、Fermat Testの当てはまり度、pのリスト")
print("回数=4")
print(gen_prime(100,4) )
# Out:
# Fermat Testを通したpの数、実際に素数のpの数、Fermat Testの当てはまり度、pのリスト
# 回数=4
# ...

# %%
print("Fermat Testを通したpの数、実際に素数のpの数、Fermat Testの当てはまり度、pのリスト")
print("回数=5")
print(gen_prime(100,5) )
# Out:
# Fermat Testを通したpの数、実際に素数のpの数、Fermat Testの当てはまり度、pのリスト
# 回数=5
# ...

# %%
import matplotlib.pyplot as plt
(c,y1,a,b)=gen_prime(100,1)
(c,y2,a,b)=gen_prime(100,2)
(c,y3,a,b)=gen_prime(100,3)
(c,y4,a,b)=gen_prime(100,4)
(c,y5,a,b)=gen_prime(100,5)
plt.plot([1,2,3,4,5],[y1,y2,y3,y4,y5])
plt.xlabel('Number of times repeat Fermat')
plt.ylabel('Number of actual primes out of 100 fermat primes')
plt.show()

# %%
print('グラフからわかるように、「fermatの回数」と「正しい素数の数」の間に非線形な関係がある。この曲線は指数的であると考えられる。')
# Out:
# グラフからわかるように、「fermatの回数」と「正しい素数の数」の間に非線形な関係がある。この曲線は指数的であると考えられる。
